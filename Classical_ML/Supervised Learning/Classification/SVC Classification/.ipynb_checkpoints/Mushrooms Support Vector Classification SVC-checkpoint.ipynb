# %%
import numpy as np
import pandas as pd

# %%
mushroom_dataframe = pd.read_csv(r"C:\Users\User\Documents\BFO Berufsfachschule Oberwallis\Module\Modul Md259 - Machine Learning\mushrooms.csv", delimiter = ';')

# %%
mushroom_dataframe
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# ...

# %%
df = mushroom_dataframe

# %%
df.columns
# Out:
# Index(['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed',
#        'gill-attachment', 'gill-spacing', 'gill-color', 'stem-height', 'stem-width', 'stem-root',
#        'stem-surface', 'stem-color', 'veil-type', 'veil-color', 'has-ring', 'ring-type',
#        'spore-print-color', 'habitat', 'season'],
#       dtype='object')

# %%
df = df.rename(columns={'class':"class", 'cap-diameter':"cap_diameter", 'cap-shape':"cap_shape", 'cap-surface':"cap_surface", 'cap-color':"cap_color", 'does-bruise-or-bleed':"does_bruise_or_bleed",
       'gill-attachment':"gill_attachment", 'gill-spacing':"gill_spacing", 'gill-color':"gill_color", 'stem-height':"stem_height", 'stem-width':"stem_width", 'stem-root':"stem_root",
       'stem-surface':"stem_surface", 'stem-color':"stem_color", 'veil-type':"veil_type", 'veil-color':"veil_color", 'has-ring':"has_ring", 'ring-type':"ring_type",
       'spore-print-color':"Spore_print_color", 'habitat':"habitat", 'season':"season"})

# %%
df.dtypes
# Out:
# class                    object
# cap_diameter            float64
# cap_shape                object
# cap_surface              object
# cap_color                object
# does_bruise_or_bleed     object
# gill_attachment          object
# gill_spacing             object
# gill_color               object
# stem_height             float64
# stem_width              float64
# stem_root                object
# stem_surface             object
# stem_color               object
# veil_type                object
# veil_color               object
# has_ring                 object
# ring_type                object
# Spore_print_color        object
# habitat                  object
# season                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap_diameter          61069 non-null  float64
#  2   cap_shape             61069 non-null  object
#  3   cap_surface           46949 non-null  object
#  4   cap_color             61069 non-null  object
#  5   does_bruise_or_bleed  61069 non-null  object
#  6   gill_attachment       51185 non-null  object
#  7   gill_spacing          36006 non-null  object
#  8   gill_color            61069 non-null  object
#  9   stem_height           61069 non-null  float64
#  10  stem_width            61069 non-null  float64
#  11  stem_root             9531 non-null   object
#  12  stem_surface          22945 non-null  object
#  13  stem_color            61069 non-null  object
#  14  veil_type             3177 non-null   object
# ...

# %%
df.describe()
# Out:
#        cap_diameter   stem_height    stem_width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %%
import matplotlib.pyplot as plt
path_to_output = r"C:\Users\User\Documents\BFO Berufsfachschule Oberwallis\Module\Modul Md259 - Machine Learning"
df.plot(x="cap_diameter", y="stem_height", kind='scatter') 
plt.title('Mushrooms Diameter vs Height') 
plt.xlabel('Cap Diameter') 
plt.ylabel('Stem Height')
plt.savefig(path_to_output + 'testplot.png', bbox_inches='tight')

# %%
import sklearn as sl

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop("class", axis=1)

# %%
x
# Out:
#        cap_diameter cap_shape cap_surface cap_color does_bruise_or_bleed gill_attachment  \
# 0             15.26         x           g         o                    f               e
# 1             16.60         x           g         o                    f               e
# 2             14.07         x           g         o                    f               e
# 3             14.17         f           h         e                    f               e
# 4             14.64         x           h         o                    f               e
# ...             ...       ...         ...       ...                  ...             ...
# 61064          1.18         s           s         y                    f               f
# 61065          1.27         f           s         y                    f               f
# 61066          1.27         s           s         y                    f               f
# ...

# %%
x.cap_shape=df.cap_shape.astype('category').cat.codes
x.cap_surface=df.cap_surface.astype('category').cat.codes
x.cap_color=df.cap_color.astype('category').cat.codes
x.gill_attachment=df.gill_attachment.astype('category').cat.codes
x.does_bruise_or_bleed=df.does_bruise_or_bleed.astype('category').cat.codes
x.gill_spacing=df.gill_spacing.astype('category').cat.codes
x.gill_color=df.gill_color.astype('category').cat.codes
x.stem_root=df.stem_root.astype('category').cat.codes
x.stem_surface=df.stem_surface.astype('category').cat.codes
x.stem_color=df.stem_color.astype('category').cat.codes
x.veil_type=df.veil_type.astype('category').cat.codes
x.veil_color=df.veil_color.astype('category').cat.codes
x.has_ring=df.has_ring.astype('category').cat.codes
x.ring_type=df.ring_type.astype('category').cat.codes
x.Spore_print_color=df.Spore_print_color.astype('category').cat.codes
x.habitat=df.habitat.astype('category').cat.codes
x.season=df.season.astype('category').cat.codes
x
# Out:
#        cap_diameter  cap_shape  cap_surface  cap_color  does_bruise_or_bleed  gill_attachment  \
# 0             15.26          6            2          6                     0                2
# 1             16.60          6            2          6                     0                2
# 2             14.07          6            2          6                     0                2
# 3             14.17          2            3          1                     0                2
# 4             14.64          6            3          6                     0                2
# ...             ...        ...          ...        ...                   ...              ...
# 61064          1.18          5            7         11                     0                3
# 61065          1.27          2            7         11                     0                3
# 61066          1.27          5            7         11                     0                3
# ...

# %%
df_label = df["class"].copy()

# %%
y=np.ravel(df_label)

# %%
y
# Out:
# array(['p', 'p', 'p', ..., 'p', 'p', 'p'], dtype=object)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.5, random_state=50)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
from sklearn.svm import SVC
svc_model = SVC()svc_model.fit(x_train, y_train)

# %%
svc_model.fit(x_train, y_train)
# Out:
# SVC()

# %%
SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
kernel='rbf', max_iter=-1, probability=False, random_state=None,
shrinking=True, tol=0.001, verbose=False)
# Out:
# SVC(gamma='auto_deprecated')

# %%
y_predict = svc_model.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_test
# Out:
# array(['e', 'e', 'p', ..., 'e', 'p', 'p'], dtype=object)

# %%
y_predict
# Out:
# array(['e', 'e', 'p', ..., 'e', 'p', 'p'], dtype=object)

# %%
cm = np.array(confusion_matrix(y_test, y_predict, labels=["e","p"]))

# %%
confusion = pd.DataFrame(cm, index=['e', 'p'], columns=['Predicted edible', 'Predicted poisonous'])

# %%
import seaborn as sns
sns.heatmap(confusion,annot=True,fmt='g')
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            e       0.99      0.99      0.99     13621
#            p       0.99      0.99      0.99     16914
#
#     accuracy                           0.99     30535
#    macro avg       0.99      0.99      0.99     30535
# weighted avg       0.99      0.99      0.99     30535
