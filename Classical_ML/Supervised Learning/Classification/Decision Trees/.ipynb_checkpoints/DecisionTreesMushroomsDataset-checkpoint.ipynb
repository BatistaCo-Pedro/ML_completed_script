# %%
#mushroom data set decision tree

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn import metrics
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mushroom_dataframe = pd.read_csv(r"C:\Users\User\Documents\BFO Berufsfachschule Oberwallis\Module\Modul Md259 - Machine Learning\mushrooms.csv", delimiter = ';')

# %%
mushroom_dataframe
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# ...

# %%
mushroom_dataframe.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
mushroom_dataframe.columns
# Out:
# Index(['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
#        'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
#        'habitat', 'season'],
#       dtype='object')

# %%
mushroom_dataframe = mushroom_dataframe.rename(columns={'class':"class", 'cap-diameter':"cap_diameter", 'cap-shape':"cap_shape", 'cap-surface':"cap_surface", 'cap-color':"cap_color", 'does-bruise-or-bleed':"does_bruise_or_bleed",
       'gill-attachment':"gill_attachment", 'gill-spacing':"gill_spacing", 'gill-color':"gill_color", 'stem-height':"stem_height", 'stem-width':"stem_width", 'stem-root':"stem_root",
       'stem-surface':"stem_surface", 'stem-color':"stem_color", 'veil-type':"veil_type", 'veil-color':"veil_color", 'has-ring':"has_ring", 'ring-type':"ring_type",
       'spore-print-color':"Spore_print_color", 'habitat':"habitat", 'season':"season"})

# %%
import sklearn as sl

# %%
from sklearn.model_selection import train_test_split

# %%
x = mushroom_dataframe.drop("class", axis=1)
x
# Out:
#        cap_diameter cap_shape cap_surface cap_color does_bruise_or_bleed  \
# 0             15.26         x           g         o                    f
# 1             16.60         x           g         o                    f
# 2             14.07         x           g         o                    f
# 3             14.17         f           h         e                    f
# 4             14.64         x           h         o                    f
# ...             ...       ...         ...       ...                  ...
# 61064          1.18         s           s         y                    f
# 61065          1.27         f           s         y                    f
# 61066          1.27         s           s         y                    f
# 61067          1.24         f           s         y                    f
# 61068          1.17         s           s         y                    f
#
#       gill_attachment gill_spacing gill_color  stem_height  stem_width  \
# ...

# %%
x.cap_shape=mushroom_dataframe.cap_shape.astype('category').cat.codes
x.cap_surface=mushroom_dataframe.cap_surface.astype('category').cat.codes
x.cap_color=mushroom_dataframe.cap_color.astype('category').cat.codes
x.gill_attachment=mushroom_dataframe.gill_attachment.astype('category').cat.codes
x.does_bruise_or_bleed=mushroom_dataframe.does_bruise_or_bleed.astype('category').cat.codes
x.gill_spacing=mushroom_dataframe.gill_spacing.astype('category').cat.codes
x.gill_color=mushroom_dataframe.gill_color.astype('category').cat.codes
x.stem_root=mushroom_dataframe.stem_root.astype('category').cat.codes
x.stem_surface=mushroom_dataframe.stem_surface.astype('category').cat.codes
x.stem_color=mushroom_dataframe.stem_color.astype('category').cat.codes
x.veil_type=mushroom_dataframe.veil_type.astype('category').cat.codes
x.veil_color=mushroom_dataframe.veil_color.astype('category').cat.codes
x.has_ring=mushroom_dataframe.has_ring.astype('category').cat.codes
x.ring_type=mushroom_dataframe.ring_type.astype('category').cat.codes
x.Spore_print_color=mushroom_dataframe.Spore_print_color.astype('category').cat.codes
x.habitat=mushroom_dataframe.habitat.astype('category').cat.codes
x.season=mushroom_dataframe.season.astype('category').cat.codes
x
# Out:
#        cap_diameter  cap_shape  cap_surface  cap_color  does_bruise_or_bleed  \
# 0             15.26          6            2          6                     0
# 1             16.60          6            2          6                     0
# 2             14.07          6            2          6                     0
# 3             14.17          2            3          1                     0
# 4             14.64          6            3          6                     0
# ...             ...        ...          ...        ...                   ...
# 61064          1.18          5            7         11                     0
# 61065          1.27          2            7         11                     0
# 61066          1.27          5            7         11                     0
# 61067          1.24          2            7         11                     0
# 61068          1.17          5            7         11                     0
#
# ...

# %%
df_label = mushroom_dataframe["class"].copy()

# %%
y=np.ravel(df_label)

# %%
y
# Out:
# array(['p', 'p', 'p', ..., 'p', 'p', 'p'], dtype=object)

# %%
#check if dataset label are balanced
df_label.value_counts()
# Out:
# p    33888
# e    27181
# Name: class, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.5, random_state=50)

# %%
from sklearn.datasets import load_iris
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.579372114116095, 0.975, 'X[9] <= 8.225\ngini = 0.494\nsamples = 30534\nvalue = [13560, 16974]'),
#  Text(0.3400189643799472, 0.925, 'X[6] <= 0.5\ngini = 0.426\nsamples = 12976\nvalue = [3992, 8984]'),
#  Text(0.2176368733509235, 0.875, 'X[2] <= 3.5\ngini = 0.364\nsamples = 10178\nvalue = [2432, 7746]'),
#  Text(0.09226583113456464, 0.825, 'X[1] <= 0.5\ngini = 0.446\nsamples = 5152\nvalue = [1730, 3422]'),
#  Text(0.037598944591029027, 0.775, 'X[8] <= 3.675\ngini = 0.179\nsamples = 958\nvalue = [95, 863]'),
#  Text(0.02704485488126649, 0.725, 'X[5] <= -0.5\ngini = 0.13\nsamples = 100\nvalue = [93, 7]'),
#  Text(0.021767810026385226, 0.675, 'gini = 0.0\nsamples = 93\nvalue = [93, 0]'),
#  Text(0.032321899736147755, 0.675, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.048153034300791556, 0.725, 'X[8] <= 3.765\ngini = 0.005\nsamples = 858\nvalue = [2, 856]'),
#  Text(0.04287598944591029, 0.675, 'X[12] <= 8.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
# ...

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("mushrooms")
# Out:
# 'mushrooms.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, feature_names=x.columns.tolist(),class_names=y,filled=True, rounded=True,special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
test_pred_decision_tree = clf.predict(x_test)

# %%
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt

confusion_matrix = metrics.confusion_matrix(y_test,test_pred_decision_tree, labels=["e","p"])
matrix_df = pd.DataFrame(confusion_matrix, index=['e', 'p'], columns=['Predicted edible', 'Predicted poisonous'])

ax = plt.axes()

sns.set(font_scale=1.3)
plt.figure(figsize=(10,7))
sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
ax.set_title('Confusion Matrix - Decision Tree')

ax.set_xlabel("Predicted label", fontsize =15)

ax.set_ylabel("True Label", fontsize=15)

plt.show()
