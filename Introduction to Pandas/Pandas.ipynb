# %%
import numpy as np
import pandas as pd

# %%
d = {'a': 1, 'b': 2, 'c': 3}
ser = pd.Series(data=d, index=['a', 'b', 'c'])
ser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser.iloc[0] = 999
ser
# Out:
# a    999
# b      2
# c      3
# dtype: int64

# %%
pd.read_csv(r"C:\Users\User\Documents\BFO Berufsfachschule Oberwallis\Module\Modul Md259 - Machine Learning\Zoo.csv", delimiter = ',')
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
mushroom_dataframe = pd.read_csv(r"C:\Users\User\Documents\BFO Berufsfachschule Oberwallis\Module\Modul Md259 - Machine Learning\mushrooms.csv", delimiter = ';')

# %%
mushroom_dataframe
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# ...

# %%
mushroom_dataframe.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
pd.set_option('display.width', 100)

# %%
df = mushroom_dataframe

# %%
df.loc[:,"class"]
# Out:
# 0        p
# 1        p
# 2        p
# 3        p
# 4        p
#         ..
# 61064    p
# 61065    p
# 61066    p
# 61067    p
# 61068    p
# Name: class, Length: 61069, dtype: object

# %%
df.columns
# Out:
# Index(['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed',
#        'gill-attachment', 'gill-spacing', 'gill-color', 'stem-height', 'stem-width', 'stem-root',
#        'stem-surface', 'stem-color', 'veil-type', 'veil-color', 'has-ring', 'ring-type',
#        'spore-print-color', 'habitat', 'season'],
#       dtype='object')

# %%
df = df.rename(columns={'class':"class", 'cap-diameter':"cap_diameter", 'cap-shape':"cap_shape", 'cap-surface':"cap_surface", 'cap-color':"cap_color", 'does-bruise-or-bleed':"does_bruise_or_bleed",
       'gill-attachment':"gill_attachment", 'gill-spacing':"gill_spacing", 'gill-color':"gill_color", 'stem-height':"stem_height", 'stem-width':"stem_width", 'stem-root':"stem_root",
       'stem-surface':"stem_surface", 'stem-color':"stem_color", 'veil-type':"veil_type", 'veil-color':"veil_color", 'has-ring':"has_ring", 'ring-type':"ring_type",
       'spore-print-color':"Spore_print_color", 'habitat':"habitat", 'season':"season"})

# %%
df["cap_diameter"].min()
# Out:
# 0.38

# %%
df.dtypes
# Out:
# class                    object
# cap_diameter            float64
# cap_shape                object
# cap_surface              object
# cap_color                object
# does_bruise_or_bleed     object
# gill_attachment          object
# gill_spacing             object
# gill_color               object
# stem_height             float64
# stem_width              float64
# stem_root                object
# stem_surface             object
# stem_color               object
# veil_type                object
# veil_color               object
# has_ring                 object
# ring_type                object
# Spore_print_color        object
# habitat                  object
# season                   object
# dtype: object

# %%
df["cap_diameter"].unique()
# Out:
# array([15.26, 16.6 , 14.07, ..., 22.85, 21.8 , 20.42])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap_diameter          61069 non-null  float64
#  2   cap_shape             61069 non-null  object
#  3   cap_surface           46949 non-null  object
#  4   cap_color             61069 non-null  object
#  5   does_bruise_or_bleed  61069 non-null  object
#  6   gill_attachment       51185 non-null  object
#  7   gill_spacing          36006 non-null  object
#  8   gill_color            61069 non-null  object
#  9   stem_height           61069 non-null  float64
#  10  stem_width            61069 non-null  float64
#  11  stem_root             9531 non-null   object
#  12  stem_surface          22945 non-null  object
#  13  stem_color            61069 non-null  object
#  14  veil_type             3177 non-null   object
# ...

# %%
df.describe()
# Out:
#        cap_diameter   stem_height    stem_width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %%
import matplotlib.pyplot as plt
path_to_output = r"C:\Users\User\Documents\BFO Berufsfachschule Oberwallis\Module\Modul Md259 - Machine Learning"
df.plot(x="cap_diameter", y="stem_height", kind='scatter') 
plt.title('Mushrooms Diameter vs Height') 
plt.xlabel('Cap Diameter') 
plt.ylabel('Stem Height')
plt.savefig(path_to_output + 'testplot.png', bbox_inches='tight')

# %%
grouped = df.groupby(df.habitat)

# %%
grouped.get_group('d')
# Out:
#       class  cap_diameter cap_shape cap_surface cap_color does_bruise_or_bleed gill_attachment  \
# 0         p         15.26         x           g         o                    f               e
# 1         p         16.60         x           g         o                    f               e
# 2         p         14.07         x           g         o                    f               e
# 3         p         14.17         f           h         e                    f               e
# 4         p         14.64         x           h         o                    f               e
# ...     ...           ...       ...         ...       ...                  ...             ...
# 61064     p          1.18         s           s         y                    f               f
# 61065     p          1.27         f           s         y                    f               f
# 61066     p          1.27         s           s         y                    f               f
# ...

# %%
print("Number of null values in column gill_spacing : " + str(df.gill_spacing.isna().sum()))
# Out:
# Number of null values in column gill_spacing : 25063

# %%
df.gill_spacing.isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 61064    False
# 61065    False
# 61066    False
# 61067    False
# 61068    False
# Name: gill_spacing, Length: 61069, dtype: bool
